# %%
oacmaroon='#800000'
oacgold='#808000'

# %%
p = plot([e^(0.4*x), e^0.4 + 0.4*(e^0.4)*(x-1)], (x, -1, 3), ymin=0, ymax=3, axes_labels=['$x$','$y$'], legend_label=["$y=f(x)$", "Slope at $x=1$"], thickness=5, color=[oacmaroon, oacgold], aspect_ratio=1, gridlines=True, gridlinesstyle=dict(linewidth=1, linestyle="-"), zorder=3)
p.axes_width(5)
p.fontsize(20)
p.show()
p.save('ex0-1.png')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f(x) = e^(0.4*x)
p = plot(f(x), (x, -1, 3), ymin=0, ymax=3, axes_labels=['$x$','$y$'], legend_label="$y=f(x)$", thickness=5, color=oacmaroon, aspect_ratio=1, gridlines=True, gridlinesstyle=dict(linewidth=1, linestyle="-"), zorder=4)+plot(e^(0.4*x), (x, 0.5, 2.5), ymin=0, ymax=3, axes_labels=['$x$','$y$'], thickness=5, color=oacmaroon, aspect_ratio=1, gridlines=True, gridlinesstyle=dict(linewidth=1, linestyle="-"), zorder=3, fill=True, fillcolor=oacgold)+line([(0.5,0),(0.5,f(0.5))], color='black', thickness=2) + line([(2.5,0),(2.5,f(2.5))], color='black', thickness=2) 
p.axes_width(5)
p.fontsize(20)
p.show()
p.save('ex0-2.png')
# Out:
# Graphics object consisting of 5 graphics primitives
