# %%
from sage.plot.scatter_plot import ScatterPlot

oacmaroon='#800000'
oacgold='#808000'

# %%
f(x) = 5.76*x^3 - 109.98*x^2 + 532.58*x + 70.17
p = plot(f(x), (x, 0.5, 13), axes_labels=['$m$','$f$'], thickness=5, color=oacmaroon, gridlines=True, gridlinesstyle=dict(linewidth=1, linestyle="-"), zorder=3)
p.axes_width(5)
p.fontsize(20)
p.show()
p.save('fig1-3-oil.png')
# Out:
# Graphics object consisting of 1 graphics primitive
